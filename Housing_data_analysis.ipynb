# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("dataset/Housing.txt")
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df.shape
# Out:
# (545, 13)

# %%
df.sample(10)
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 361   3710000  6020         3          1        1      yes        no       no
# 86    6510000  6670         3          1        3      yes        no      yes
# 5    10850000  7500         3          3        1      yes        no      yes
# 509   2590000  3600         2          2        2      yes        no      yes
# 344   3850000  3850         2          1        1      yes        no       no
# 323   4025000  5400         3          1        1      yes        no       no
# 530   2240000  1950         3          1        1       no        no       no
# 154   5530000  3650         3          2        2      yes        no       no
# 484   2870000  3040         2          1        1       no        no       no
# 65    6930000  8880         3          2        2      yes        no      yes
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
df['furnishingstatus'].unique()
# Out:
# array(['furnished', 'semi-furnished', 'unfurnished'], dtype=object)

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder,OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split

# %%
x = pd.DataFrame(df)

# %%
x.drop(columns=['price'],inplace=True)

# %%
x
# Out:
#      area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    7420         4          2        3      yes        no       no
# 1    8960         4          4        4      yes        no       no
# 2    9960         3          2        2      yes        no      yes
# 3    7500         4          2        2      yes        no      yes
# 4    7420         4          1        2      yes       yes      yes
# ..    ...       ...        ...      ...      ...       ...      ...
# 540  3000         2          1        1      yes        no      yes
# 541  2400         3          1        1       no        no       no
# 542  3620         2          1        1      yes        no       no
# 543  2910         3          1        1       no        no       no
# 544  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0                no             yes        2      yes        furnished
# ...

# %%
y = pd.DataFrame(df['price'])

# %%
y
# Out:
#         price
# 0    13300000
# 1    12250000
# 2    12250000
# 3    12215000
# 4    11410000
# ..        ...
# 540   1820000
# 541   1767150
# 542   1750000
# 543   1750000
# 544   1750000
#
# [545 rows x 1 columns]

# %%
 X_train,X_test,Y_train,Y_test =train_test_split(x , y , train_size=0.8, random_state=2)

# %%
X_train
# Out:
#      area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 412  2610         3          1        2      yes        no      yes
# 284  7770         2          1        1      yes        no       no
# 504  3185         2          1        1      yes        no       no
# 209  6720         3          1        1      yes        no       no
# 269  3900         3          1        2      yes        no       no
# ..    ...       ...        ...      ...      ...       ...      ...
# 299  7000         3          1        1      yes        no       no
# 534  3000         4          1        2      yes        no       no
# 493  3960         3          1        1      yes        no       no
# 527  1836         2          1        1       no        no      yes
# 168  4260         4          1        2      yes        no      yes
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 412              no              no        0      yes      unfurnished
# ...

# %%
X_train.shape
# Out:
# (436, 12)

# %%
X_test
# Out:
#      area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 333  3000         3          1        2      yes        no       no
# 84   3760         3          1        2      yes        no       no
# 439  3930         2          1        1       no        no       no
# 396  3640         2          1        1      yes        no       no
# 161  6100         3          1        3      yes       yes       no
# ..    ...       ...        ...      ...      ...       ...      ...
# 100  6600         3          2        1      yes        no      yes
# 344  3850         2          1        1      yes        no       no
# 176  8520         3          1        1      yes        no       no
# 244  5320         3          1        2      yes       yes      yes
# 15   6000         4          1        2      yes        no      yes
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 333              no              no        0       no   semi-furnished
# ...

# %%
Y_train
# Out:
#        price
# 412  3430000
# 284  4270000
# 504  2653000
# 209  4900000
# 269  4375000
# ..       ...
# 299  4200000
# 534  2100000
# 493  2800000
# 527  2275000
# 168  5250000
#
# [436 rows x 1 columns]

# %%
Y_test.shape
# Out:
# (109, 1)

# %%
Y_test
# Out:
#        price
# 333  3920000
# 84   6510000
# 439  3255000
# 396  3500000
# 161  5460000
# ..       ...
# 100  6230000
# 344  3850000
# 176  5250000
# 244  4550000
# 15   9100000
#
# [109 rows x 1 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder,OneHotEncoder

# %%
tr = ColumnTransformer(transformers = [
    ('t1',OneHotEncoder(drop='first',sparse=False),['mainroad','guestroom','basement','hotwaterheating','airconditioning','parking','prefarea']),
    ('t2',OrdinalEncoder(categories=[['furnished','semi-furnished','unfurnished']]),['furnishingstatus'])
],remainder='passthrough')

# %%
tr
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('t1',
#                                  OneHotEncoder(drop='first', sparse=False),
#                                  ['mainroad', 'guestroom', 'basement',
#                                   'hotwaterheating', 'airconditioning',
#                                   'parking', 'prefarea']),
#                                 ('t2',
#                                  OrdinalEncoder(categories=[['furnished',
#                                                              'semi-furnished',
#                                                              'unfurnished']]),
#                                  ['furnishingstatus'])])

# %%
a = tr.fit_transform(X_train)
a
a.shape
# Out:
# (436, 14)

# %%
b = tr.fit_transform(X_test)
b
# Out:
# array([[1., 0., 0., ..., 3., 1., 2.],
#        [1., 0., 0., ..., 3., 1., 2.],
#        [0., 0., 0., ..., 2., 1., 1.],
#        ...,
#        [1., 0., 0., ..., 3., 1., 1.],
#        [1., 1., 1., ..., 3., 1., 2.],
#        [1., 0., 1., ..., 4., 1., 2.]])

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(a,Y_train)
# Out:
# LinearRegression()

# %%
lr.predict(b)
# Out:
# array([[3223743.41984925],
#        [4820203.53203647],
#        [2276429.91515828],
#        [3217382.99235242],
#        [6317141.84299058],
#        [4133639.2085408 ],
#        [3676242.42221272],
#        [3038160.96185865],
#        [4049124.44411955],
#        [3206040.89371854],
#        [3714838.50892892],
#        [3078342.54722531],
#        [3750352.79763176],
#        [5105669.98981182],
#        [4894701.61617368],
#        [6929570.31429155],
#        [7306026.33380337],
#        [4672132.00371793],
#        [2880520.0764426 ],
#        [4489464.05228311],
#        [5508483.72221125],
#        [4746441.92126959],
#        [4831582.61430871],
#        [6481816.12409204],
#        [2024521.1980391 ],
#        [2635264.7831384 ],
#        [2688425.76545536],
#        [4362586.40459228],
#        [4954140.8220693 ],
#        [3366106.24500077],
#        [5051310.784705  ],
#        [4100222.01714788],
#        [3896650.25956256],
#        [4911592.59964415],
# ...

# %%
lr.score(a,Y_train)
# Out:
# 0.6902465420043364

# %%
lr.score(b,Y_test)
# Out:
# 0.6400292422238207
