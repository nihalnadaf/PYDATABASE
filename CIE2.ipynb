# %% [markdown]
# How to handle the missing values in the dataset? Explain.

# %% [markdown]
# Describe univariate, bivariate, and multivariate analysis with suitable examples.

# %% [markdown]
# import Librarirs

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Load dataset

# %%
df = pd.read_csv('dataset/titanic.csv')
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 629          630       0.0       3      O'Connell, Mr. Patrick D    male
# 235          236       0.0       3  Harknett, Miss. Alice Phoebe  female
# 404          405       0.0       3       Oreskovic, Miss. Marija  female
# 853          854       1.0       1     Lines, Miss. Mary Conover  female
# 289          290       1.0       3          Connolly, Miss. Kate  female
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 629   NaN      0      0      334912   7.7333   NaN        Q
# 235   NaN      0      0  W./C. 6609   7.5500   NaN        S
# 404  20.0      0      0      315096   8.6625   NaN        S
# 853  16.0      0      1    PC 17592  39.4000   D28        S
# 289  22.0      0      0      370373   7.7500   NaN        Q

# %% [markdown]
# Identify Numerical, nominal-categorical, and ordinal-categorical variables types

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  887.000000  891.000000  713.000000  891.000000
# mean    446.000000    0.382187    2.308642   29.704306    0.523008
# std     257.353842    0.486196    0.836071   14.536033    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  888.000000
# mean     0.381594   32.282530
# std      0.806057   49.758986
# min      0.000000    0.000000
# 25%      0.000000    7.917700
# 50%      0.000000   14.456250
# 75%      0.000000   31.068750
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     887 non-null    float64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          713 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         888 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 83.7+ KB

# %%
Numerical: PassengerId, Age, Pclass, SibSb, Parch, Fare.
Nominal-categorical: Sex, Embarked
Ordinal-categorical
# Out:
#   Input In [9]
#     Numerical: PassengerId, Age, Pclass, SibSb, Parch, Fare.
#                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# EDA

# %%
import seaborn as sns
sns.pairplot(df)

# %% [markdown]
# find and replace missing values

# %% [markdown]
# Outliers

# %% [markdown]
# data intergration

# %% [markdown]
# data reduction

# %% [markdown]
# transformations
